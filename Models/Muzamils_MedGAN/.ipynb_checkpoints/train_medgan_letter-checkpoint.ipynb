# %% [markdown]
# ## Imports

# %%
from medgan_model import Medgan
from data_loader import load_letter_data
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
import pandas as pd

# %%
from medgan_model import Medgan
from data_loader import load_letter_data
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Load and Preprocess Data

# %%
# --- Load and preprocess real shuttle data ---
df = pd.read_csv("datasets/letter-recognition-2.csv", header=None)
X_real = df.iloc[:, :-1]
y_real = df.iloc[:, -1]

# %%
# --- Load data without labels for GAN training ---
X_train, X_test = load_letter_data("datasets/letter-recognition-2.csv")
input_dim = X_train.shape[1]

# %%
# --- Load Data ---
X_train, X_test = load_letter_data("datasets/letter-recognition-2.csv")
input_dim = X_train.shape[1]

# %% [markdown]
# ## Initialize and Train MedGAN

# %%
# --- Initialize and Train MedGAN ---
medgan = Medgan(input_dim=input_dim, ae_loss_type='bce')
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002)
batch_size = 64
n_epochs = 300

for epoch in range(n_epochs):
    np.random.shuffle(X_train)
    for i in range(0, len(X_train), batch_size):
        batch = X_train[i:i + batch_size]
        noise = np.random.normal(size=(batch.shape[0], medgan.random_dim))
        medgan.train_step(batch, noise)
    print(f"Epoch {epoch+1}/{n_epochs} completed")
# Out:
# Epoch 1/300 completed
# Epoch 2/300 completed
# Epoch 3/300 completed
# Epoch 4/300 completed
# Epoch 5/300 completed
# Epoch 6/300 completed
# Epoch 7/300 completed
# Epoch 8/300 completed
# Epoch 9/300 completed
# Epoch 10/300 completed
# Epoch 11/300 completed
# Epoch 12/300 completed
# Epoch 13/300 completed
# Epoch 14/300 completed
# Epoch 15/300 completed
# Epoch 16/300 completed
# Epoch 17/300 completed
# Epoch 18/300 completed
# Epoch 19/300 completed
# Epoch 20/300 completed
# Epoch 21/300 completed
# Epoch 22/300 completed
# Epoch 23/300 completed
# Epoch 24/300 completed
# Epoch 25/300 completed
# Epoch 26/300 completed
# Epoch 27/300 completed
# Epoch 28/300 completed
# Epoch 29/300 completed
# Epoch 30/300 completed
# Epoch 31/300 completed
# Epoch 32/300 completed
# Epoch 33/300 completed
# Epoch 34/300 completed
# Epoch 35/300 completed
# Epoch 36/300 completed
# Epoch 37/300 completed
# Epoch 38/300 completed
# Epoch 39/300 completed
# Epoch 40/300 completed
# Epoch 41/300 completed
# Epoch 42/300 completed
# Epoch 43/300 completed
# Epoch 44/300 completed
# Epoch 45/300 completed
# Epoch 46/300 completed
# Epoch 47/300 completed
# Epoch 48/300 completed
# Epoch 49/300 completed
# Epoch 50/300 completed
# Epoch 51/300 completed
# Epoch 52/300 completed
# Epoch 53/300 completed
# Epoch 54/300 completed
# Epoch 55/300 completed
# Epoch 56/300 completed
# Epoch 57/300 completed
# Epoch 58/300 completed
# Epoch 59/300 completed
# Epoch 60/300 completed
# Epoch 61/300 completed
# Epoch 62/300 completed
# Epoch 63/300 completed
# Epoch 64/300 completed
# Epoch 65/300 completed
# Epoch 66/300 completed
# Epoch 67/300 completed
# Epoch 68/300 completed
# Epoch 69/300 completed
# Epoch 70/300 completed
# Epoch 71/300 completed
# Epoch 72/300 completed
# Epoch 73/300 completed
# Epoch 74/300 completed
# Epoch 75/300 completed
# Epoch 76/300 completed
# Epoch 77/300 completed
# Epoch 78/300 completed
# Epoch 79/300 completed
# Epoch 80/300 completed
# Epoch 81/300 completed
# Epoch 82/300 completed
# Epoch 83/300 completed
# Epoch 84/300 completed
# Epoch 85/300 completed
# Epoch 86/300 completed
# Epoch 87/300 completed
# Epoch 88/300 completed
# Epoch 89/300 completed
# Epoch 90/300 completed
# Epoch 91/300 completed
# Epoch 92/300 completed
# Epoch 93/300 completed
# Epoch 94/300 completed
# Epoch 95/300 completed
# Epoch 96/300 completed
# Epoch 97/300 completed
# Epoch 98/300 completed
# Epoch 99/300 completed
# Epoch 100/300 completed
# Epoch 101/300 completed
# Epoch 102/300 completed
# Epoch 103/300 completed
# Epoch 104/300 completed
# Epoch 105/300 completed
# Epoch 106/300 completed
# Epoch 107/300 completed
# Epoch 108/300 completed
# Epoch 109/300 completed
# Epoch 110/300 completed
# Epoch 111/300 completed
# Epoch 112/300 completed
# Epoch 113/300 completed
# Epoch 114/300 completed
# Epoch 115/300 completed
# Epoch 116/300 completed
# Epoch 117/300 completed
# Epoch 118/300 completed
# Epoch 119/300 completed
# Epoch 120/300 completed
# Epoch 121/300 completed
# Epoch 122/300 completed
# Epoch 123/300 completed
# Epoch 124/300 completed
# Epoch 125/300 completed
# Epoch 126/300 completed
# Epoch 127/300 completed
# Epoch 128/300 completed
# Epoch 129/300 completed
# Epoch 130/300 completed
# Epoch 131/300 completed
# Epoch 132/300 completed
# Epoch 133/300 completed
# Epoch 134/300 completed
# Epoch 135/300 completed
# Epoch 136/300 completed
# Epoch 137/300 completed
# Epoch 138/300 completed
# Epoch 139/300 completed
# Epoch 140/300 completed
# Epoch 141/300 completed
# Epoch 142/300 completed
# Epoch 143/300 completed
# Epoch 144/300 completed
# Epoch 145/300 completed
# Epoch 146/300 completed
# Epoch 147/300 completed
# Epoch 148/300 completed
# Epoch 149/300 completed
# Epoch 150/300 completed
# Epoch 151/300 completed
# Epoch 152/300 completed
# Epoch 153/300 completed
# Epoch 154/300 completed
# Epoch 155/300 completed
# Epoch 156/300 completed
# Epoch 157/300 completed
# Epoch 158/300 completed
# Epoch 159/300 completed
# Epoch 160/300 completed
# Epoch 161/300 completed
# Epoch 162/300 completed
# Epoch 163/300 completed
# Epoch 164/300 completed
# Epoch 165/300 completed
# Epoch 166/300 completed
# Epoch 167/300 completed
# Epoch 168/300 completed
# Epoch 169/300 completed
# Epoch 170/300 completed
# Epoch 171/300 completed
# Epoch 172/300 completed
# Epoch 173/300 completed
# Epoch 174/300 completed
# Epoch 175/300 completed
# Epoch 176/300 completed
# Epoch 177/300 completed
# Epoch 178/300 completed
# Epoch 179/300 completed
# Epoch 180/300 completed
# Epoch 181/300 completed
# Epoch 182/300 completed
# Epoch 183/300 completed
# Epoch 184/300 completed
# Epoch 185/300 completed
# Epoch 186/300 completed
# Epoch 187/300 completed
# Epoch 188/300 completed
# Epoch 189/300 completed
# Epoch 190/300 completed
# Epoch 191/300 completed
# Epoch 192/300 completed
# Epoch 193/300 completed
# Epoch 194/300 completed
# Epoch 195/300 completed
# Epoch 196/300 completed
# Epoch 197/300 completed
# Epoch 198/300 completed
# Epoch 199/300 completed
# Epoch 200/300 completed
# Epoch 201/300 completed
# Epoch 202/300 completed
# Epoch 203/300 completed
# Epoch 204/300 completed
# Epoch 205/300 completed
# Epoch 206/300 completed
# Epoch 207/300 completed
# Epoch 208/300 completed
# Epoch 209/300 completed
# Epoch 210/300 completed
# Epoch 211/300 completed
# Epoch 212/300 completed
# Epoch 213/300 completed
# Epoch 214/300 completed
# Epoch 215/300 completed
# Epoch 216/300 completed
# Epoch 217/300 completed
# Epoch 218/300 completed
# Epoch 219/300 completed
# Epoch 220/300 completed
# Epoch 221/300 completed
# Epoch 222/300 completed
# Epoch 223/300 completed
# Epoch 224/300 completed
# Epoch 225/300 completed
# Epoch 226/300 completed
# Epoch 227/300 completed
# Epoch 228/300 completed
# Epoch 229/300 completed
# Epoch 230/300 completed
# Epoch 231/300 completed
# Epoch 232/300 completed
# Epoch 233/300 completed
# Epoch 234/300 completed
# Epoch 235/300 completed
# Epoch 236/300 completed
# Epoch 237/300 completed
# Epoch 238/300 completed
# Epoch 239/300 completed
# Epoch 240/300 completed
# Epoch 241/300 completed
# Epoch 242/300 completed
# Epoch 243/300 completed
# Epoch 244/300 completed
# Epoch 245/300 completed
# Epoch 246/300 completed
# Epoch 247/300 completed
# Epoch 248/300 completed
# Epoch 249/300 completed
# Epoch 250/300 completed
# Epoch 251/300 completed
# Epoch 252/300 completed
# Epoch 253/300 completed
# Epoch 254/300 completed
# Epoch 255/300 completed
# Epoch 256/300 completed
# Epoch 257/300 completed
# Epoch 258/300 completed
# Epoch 259/300 completed
# Epoch 260/300 completed
# Epoch 261/300 completed
# Epoch 262/300 completed
# Epoch 263/300 completed
# Epoch 264/300 completed
# Epoch 265/300 completed
# Epoch 266/300 completed
# Epoch 267/300 completed
# Epoch 268/300 completed
# Epoch 269/300 completed
# Epoch 270/300 completed
# Epoch 271/300 completed
# Epoch 272/300 completed
# Epoch 273/300 completed
# Epoch 274/300 completed
# Epoch 275/300 completed
# Epoch 276/300 completed
# Epoch 277/300 completed
# Epoch 278/300 completed
# Epoch 279/300 completed
# Epoch 280/300 completed
# Epoch 281/300 completed
# Epoch 282/300 completed
# Epoch 283/300 completed
# Epoch 284/300 completed
# Epoch 285/300 completed
# Epoch 286/300 completed
# Epoch 287/300 completed
# Epoch 288/300 completed
# Epoch 289/300 completed
# Epoch 290/300 completed
# Epoch 291/300 completed
# Epoch 292/300 completed
# Epoch 293/300 completed
# Epoch 294/300 completed
# Epoch 295/300 completed
# Epoch 296/300 completed
# Epoch 297/300 completed
# Epoch 298/300 completed
# Epoch 299/300 completed
# Epoch 300/300 completed

# %%
medgan = Medgan(input_dim=input_dim, ae_loss_type='bce')

# %%
# --- Initialize and Compile Model ---
medgan = Medgan(input_dim=input_dim, ae_loss_type='bce')  # or 'mse' for real-valued
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002)

# %%
# --- Training Loop ---
ae_losses, d_losses, g_losses = [], [], []

for epoch in range(n_epochs):
    np.random.shuffle(X_train)
    for i in range(0, len(X_train), batch_size):
        batch = X_train[i:i + batch_size]
        noise = np.random.normal(size=(batch.shape[0], medgan.random_dim))
        ae_loss, d_loss, g_loss = medgan.train_step(batch, noise)

    ae_losses.append(ae_loss.numpy())
    d_losses.append(d_loss.numpy())
    g_losses.append(g_loss.numpy())

    print(f"Epoch {epoch + 1}/{n_epochs} | AE: {ae_loss:.4f}, D: {d_loss:.4f}, G: {g_loss:.4f}")
# Out:
# Epoch 1/300 | AE: 0.6904, D: 1.3977, G: 0.6259
# Epoch 2/300 | AE: 0.6900, D: 1.4051, G: 0.6257
# Epoch 3/300 | AE: 0.6905, D: 1.3996, G: 0.6273
# Epoch 4/300 | AE: 0.6902, D: 1.4009, G: 0.6261
# Epoch 5/300 | AE: 0.6903, D: 1.4031, G: 0.6267
# Epoch 6/300 | AE: 0.6902, D: 1.3968, G: 0.6283
# Epoch 7/300 | AE: 0.6899, D: 1.4002, G: 0.6268
# Epoch 8/300 | AE: 0.6905, D: 1.4050, G: 0.6265
# Epoch 9/300 | AE: 0.6898, D: 1.3981, G: 0.6260
# Epoch 10/300 | AE: 0.6897, D: 1.4005, G: 0.6252
# Epoch 11/300 | AE: 0.6893, D: 1.3996, G: 0.6286
# Epoch 12/300 | AE: 0.6909, D: 1.4004, G: 0.6279
# Epoch 13/300 | AE: 0.6903, D: 1.3998, G: 0.6239
# Epoch 14/300 | AE: 0.6909, D: 1.4035, G: 0.6271
# Epoch 15/300 | AE: 0.6907, D: 1.3920, G: 0.6247
# Epoch 16/300 | AE: 0.6900, D: 1.3971, G: 0.6278
# Epoch 17/300 | AE: 0.6904, D: 1.4013, G: 0.6263
# Epoch 18/300 | AE: 0.6889, D: 1.4050, G: 0.6251
# Epoch 19/300 | AE: 0.6902, D: 1.3942, G: 0.6282
# Epoch 20/300 | AE: 0.6902, D: 1.4018, G: 0.6265
# Epoch 21/300 | AE: 0.6905, D: 1.3945, G: 0.6283
# Epoch 22/300 | AE: 0.6908, D: 1.3981, G: 0.6235
# Epoch 23/300 | AE: 0.6895, D: 1.4048, G: 0.6245
# Epoch 24/300 | AE: 0.6905, D: 1.4031, G: 0.6272
# Epoch 25/300 | AE: 0.6901, D: 1.3999, G: 0.6277
# Epoch 26/300 | AE: 0.6913, D: 1.4068, G: 0.6257
# Epoch 27/300 | AE: 0.6902, D: 1.3965, G: 0.6266
# Epoch 28/300 | AE: 0.6900, D: 1.3989, G: 0.6255
# Epoch 29/300 | AE: 0.6905, D: 1.3998, G: 0.6255
# Epoch 30/300 | AE: 0.6903, D: 1.4034, G: 0.6223
# Epoch 31/300 | AE: 0.6908, D: 1.3966, G: 0.6289
# Epoch 32/300 | AE: 0.6897, D: 1.3969, G: 0.6275
# Epoch 33/300 | AE: 0.6894, D: 1.3988, G: 0.6282
# Epoch 34/300 | AE: 0.6900, D: 1.3981, G: 0.6246
# Epoch 35/300 | AE: 0.6907, D: 1.3980, G: 0.6281
# Epoch 36/300 | AE: 0.6904, D: 1.3988, G: 0.6272
# Epoch 37/300 | AE: 0.6903, D: 1.3953, G: 0.6280
# Epoch 38/300 | AE: 0.6906, D: 1.3945, G: 0.6290
# Epoch 39/300 | AE: 0.6900, D: 1.4023, G: 0.6222
# Epoch 40/300 | AE: 0.6907, D: 1.4045, G: 0.6266
# Epoch 41/300 | AE: 0.6910, D: 1.4007, G: 0.6263
# Epoch 42/300 | AE: 0.6894, D: 1.4012, G: 0.6264
# Epoch 43/300 | AE: 0.6906, D: 1.4005, G: 0.6235
# Epoch 44/300 | AE: 0.6896, D: 1.3983, G: 0.6264
# Epoch 45/300 | AE: 0.6898, D: 1.4030, G: 0.6267
# Epoch 46/300 | AE: 0.6897, D: 1.3994, G: 0.6258
# Epoch 47/300 | AE: 0.6899, D: 1.4083, G: 0.6245
# Epoch 48/300 | AE: 0.6903, D: 1.4024, G: 0.6259
# Epoch 49/300 | AE: 0.6907, D: 1.3985, G: 0.6261
# Epoch 50/300 | AE: 0.6900, D: 1.4060, G: 0.6222
# Epoch 51/300 | AE: 0.6906, D: 1.3970, G: 0.6262
# Epoch 52/300 | AE: 0.6900, D: 1.4017, G: 0.6247
# Epoch 53/300 | AE: 0.6902, D: 1.4027, G: 0.6281
# Epoch 54/300 | AE: 0.6896, D: 1.4048, G: 0.6227
# Epoch 55/300 | AE: 0.6897, D: 1.3995, G: 0.6301
# Epoch 56/300 | AE: 0.6896, D: 1.4044, G: 0.6231
# Epoch 57/300 | AE: 0.6904, D: 1.3962, G: 0.6276
# Epoch 58/300 | AE: 0.6907, D: 1.4057, G: 0.6231
# Epoch 59/300 | AE: 0.6905, D: 1.3973, G: 0.6302
# Epoch 60/300 | AE: 0.6902, D: 1.3951, G: 0.6275
# Epoch 61/300 | AE: 0.6907, D: 1.4054, G: 0.6251
# Epoch 62/300 | AE: 0.6907, D: 1.3950, G: 0.6285
# Epoch 63/300 | AE: 0.6899, D: 1.4006, G: 0.6268
# Epoch 64/300 | AE: 0.6887, D: 1.3998, G: 0.6268
# Epoch 65/300 | AE: 0.6900, D: 1.4008, G: 0.6229
# Epoch 66/300 | AE: 0.6901, D: 1.3991, G: 0.6274
# Epoch 67/300 | AE: 0.6901, D: 1.3934, G: 0.6270
# Epoch 68/300 | AE: 0.6897, D: 1.4038, G: 0.6245
# Epoch 69/300 | AE: 0.6902, D: 1.4012, G: 0.6235
# Epoch 70/300 | AE: 0.6907, D: 1.3955, G: 0.6265
# Epoch 71/300 | AE: 0.6906, D: 1.4034, G: 0.6276
# Epoch 72/300 | AE: 0.6902, D: 1.4088, G: 0.6242
# Epoch 73/300 | AE: 0.6901, D: 1.3967, G: 0.6291
# Epoch 74/300 | AE: 0.6899, D: 1.4001, G: 0.6262
# Epoch 75/300 | AE: 0.6899, D: 1.3947, G: 0.6278
# Epoch 76/300 | AE: 0.6902, D: 1.3982, G: 0.6261
# Epoch 77/300 | AE: 0.6898, D: 1.4003, G: 0.6285
# Epoch 78/300 | AE: 0.6902, D: 1.4011, G: 0.6281
# Epoch 79/300 | AE: 0.6900, D: 1.3967, G: 0.6271
# Epoch 80/300 | AE: 0.6906, D: 1.3978, G: 0.6272
# Epoch 81/300 | AE: 0.6900, D: 1.3984, G: 0.6282
# Epoch 82/300 | AE: 0.6898, D: 1.4011, G: 0.6218
# Epoch 83/300 | AE: 0.6902, D: 1.4002, G: 0.6241
# Epoch 84/300 | AE: 0.6907, D: 1.4003, G: 0.6244
# Epoch 85/300 | AE: 0.6904, D: 1.4015, G: 0.6259
# Epoch 86/300 | AE: 0.6907, D: 1.3933, G: 0.6288
# Epoch 87/300 | AE: 0.6895, D: 1.4020, G: 0.6243
# Epoch 88/300 | AE: 0.6900, D: 1.4000, G: 0.6263
# Epoch 89/300 | AE: 0.6905, D: 1.3957, G: 0.6284
# Epoch 90/300 | AE: 0.6905, D: 1.4015, G: 0.6233
# Epoch 91/300 | AE: 0.6903, D: 1.3972, G: 0.6291
# Epoch 92/300 | AE: 0.6898, D: 1.4019, G: 0.6232
# Epoch 93/300 | AE: 0.6902, D: 1.3945, G: 0.6257
# Epoch 94/300 | AE: 0.6898, D: 1.3995, G: 0.6281
# Epoch 95/300 | AE: 0.6896, D: 1.4055, G: 0.6216
# Epoch 96/300 | AE: 0.6905, D: 1.3966, G: 0.6286
# Epoch 97/300 | AE: 0.6897, D: 1.4037, G: 0.6243
# Epoch 98/300 | AE: 0.6911, D: 1.3954, G: 0.6278
# Epoch 99/300 | AE: 0.6894, D: 1.3968, G: 0.6276
# Epoch 100/300 | AE: 0.6894, D: 1.3981, G: 0.6275
# Epoch 101/300 | AE: 0.6902, D: 1.4056, G: 0.6199
# Epoch 102/300 | AE: 0.6904, D: 1.4024, G: 0.6249
# Epoch 103/300 | AE: 0.6893, D: 1.4049, G: 0.6267
# Epoch 104/300 | AE: 0.6901, D: 1.4073, G: 0.6236
# Epoch 105/300 | AE: 0.6903, D: 1.3887, G: 0.6294
# Epoch 106/300 | AE: 0.6906, D: 1.3990, G: 0.6281
# Epoch 107/300 | AE: 0.6895, D: 1.4033, G: 0.6242
# Epoch 108/300 | AE: 0.6911, D: 1.4021, G: 0.6258
# Epoch 109/300 | AE: 0.6900, D: 1.3981, G: 0.6279
# Epoch 110/300 | AE: 0.6904, D: 1.4038, G: 0.6242
# Epoch 111/300 | AE: 0.6901, D: 1.3966, G: 0.6293
# Epoch 112/300 | AE: 0.6901, D: 1.3963, G: 0.6273
# Epoch 113/300 | AE: 0.6913, D: 1.3901, G: 0.6265
# Epoch 114/300 | AE: 0.6903, D: 1.4019, G: 0.6242
# Epoch 115/300 | AE: 0.6900, D: 1.3940, G: 0.6273
# Epoch 116/300 | AE: 0.6902, D: 1.3986, G: 0.6280
# Epoch 117/300 | AE: 0.6904, D: 1.3967, G: 0.6243
# Epoch 118/300 | AE: 0.6905, D: 1.3956, G: 0.6271
# Epoch 119/300 | AE: 0.6910, D: 1.4055, G: 0.6244
# Epoch 120/300 | AE: 0.6897, D: 1.4007, G: 0.6242
# Epoch 121/300 | AE: 0.6904, D: 1.4006, G: 0.6287
# Epoch 122/300 | AE: 0.6898, D: 1.4032, G: 0.6273
# Epoch 123/300 | AE: 0.6902, D: 1.3992, G: 0.6255
# Epoch 124/300 | AE: 0.6893, D: 1.3960, G: 0.6265
# Epoch 125/300 | AE: 0.6903, D: 1.4071, G: 0.6224
# Epoch 126/300 | AE: 0.6899, D: 1.3986, G: 0.6247
# Epoch 127/300 | AE: 0.6906, D: 1.3969, G: 0.6287
# Epoch 128/300 | AE: 0.6894, D: 1.4001, G: 0.6272
# Epoch 129/300 | AE: 0.6901, D: 1.4045, G: 0.6248
# Epoch 130/300 | AE: 0.6901, D: 1.3983, G: 0.6243
# Epoch 131/300 | AE: 0.6905, D: 1.4046, G: 0.6237
# Epoch 132/300 | AE: 0.6906, D: 1.3994, G: 0.6259
# Epoch 133/300 | AE: 0.6908, D: 1.3978, G: 0.6284
# Epoch 134/300 | AE: 0.6898, D: 1.4014, G: 0.6290
# Epoch 135/300 | AE: 0.6901, D: 1.3940, G: 0.6300
# Epoch 136/300 | AE: 0.6903, D: 1.3951, G: 0.6262
# Epoch 137/300 | AE: 0.6898, D: 1.3950, G: 0.6289
# Epoch 138/300 | AE: 0.6901, D: 1.4034, G: 0.6263
# Epoch 139/300 | AE: 0.6895, D: 1.3991, G: 0.6259
# Epoch 140/300 | AE: 0.6900, D: 1.3988, G: 0.6240
# Epoch 141/300 | AE: 0.6902, D: 1.4029, G: 0.6242
# Epoch 142/300 | AE: 0.6900, D: 1.4034, G: 0.6270
# Epoch 143/300 | AE: 0.6896, D: 1.4022, G: 0.6281
# Epoch 144/300 | AE: 0.6905, D: 1.4003, G: 0.6249
# Epoch 145/300 | AE: 0.6906, D: 1.3971, G: 0.6285
# Epoch 146/300 | AE: 0.6901, D: 1.3952, G: 0.6306
# Epoch 147/300 | AE: 0.6900, D: 1.4015, G: 0.6265
# Epoch 148/300 | AE: 0.6902, D: 1.3991, G: 0.6242
# Epoch 149/300 | AE: 0.6906, D: 1.3971, G: 0.6223
# Epoch 150/300 | AE: 0.6904, D: 1.3988, G: 0.6258
# Epoch 151/300 | AE: 0.6910, D: 1.3993, G: 0.6245
# Epoch 152/300 | AE: 0.6907, D: 1.3978, G: 0.6250
# Epoch 153/300 | AE: 0.6898, D: 1.3993, G: 0.6263
# Epoch 154/300 | AE: 0.6900, D: 1.4031, G: 0.6244
# Epoch 155/300 | AE: 0.6902, D: 1.4067, G: 0.6245
# Epoch 156/300 | AE: 0.6907, D: 1.4008, G: 0.6284
# Epoch 157/300 | AE: 0.6896, D: 1.3952, G: 0.6307
# Epoch 158/300 | AE: 0.6899, D: 1.4021, G: 0.6269
# Epoch 159/300 | AE: 0.6894, D: 1.4030, G: 0.6294
# Epoch 160/300 | AE: 0.6900, D: 1.4027, G: 0.6256
# Epoch 161/300 | AE: 0.6899, D: 1.4021, G: 0.6229
# Epoch 162/300 | AE: 0.6904, D: 1.3940, G: 0.6256
# Epoch 163/300 | AE: 0.6903, D: 1.4008, G: 0.6251
# Epoch 164/300 | AE: 0.6900, D: 1.3961, G: 0.6281
# Epoch 165/300 | AE: 0.6906, D: 1.3911, G: 0.6302
# Epoch 166/300 | AE: 0.6902, D: 1.4016, G: 0.6249
# Epoch 167/300 | AE: 0.6900, D: 1.3933, G: 0.6285
# Epoch 168/300 | AE: 0.6910, D: 1.4024, G: 0.6270
# Epoch 169/300 | AE: 0.6905, D: 1.3989, G: 0.6286
# Epoch 170/300 | AE: 0.6909, D: 1.4004, G: 0.6270
# Epoch 171/300 | AE: 0.6899, D: 1.3963, G: 0.6269
# Epoch 172/300 | AE: 0.6904, D: 1.4070, G: 0.6222
# Epoch 173/300 | AE: 0.6908, D: 1.4025, G: 0.6256
# Epoch 174/300 | AE: 0.6903, D: 1.4040, G: 0.6249
# Epoch 175/300 | AE: 0.6898, D: 1.4067, G: 0.6238
# Epoch 176/300 | AE: 0.6907, D: 1.4042, G: 0.6248
# Epoch 177/300 | AE: 0.6904, D: 1.4075, G: 0.6210
# Epoch 178/300 | AE: 0.6901, D: 1.4005, G: 0.6279
# Epoch 179/300 | AE: 0.6901, D: 1.3987, G: 0.6264
# Epoch 180/300 | AE: 0.6898, D: 1.3996, G: 0.6238
# Epoch 181/300 | AE: 0.6904, D: 1.3954, G: 0.6272
# Epoch 182/300 | AE: 0.6901, D: 1.3980, G: 0.6270
# Epoch 183/300 | AE: 0.6908, D: 1.4045, G: 0.6199
# Epoch 184/300 | AE: 0.6901, D: 1.4028, G: 0.6203
# Epoch 185/300 | AE: 0.6894, D: 1.3997, G: 0.6245
# Epoch 186/300 | AE: 0.6906, D: 1.4035, G: 0.6236
# Epoch 187/300 | AE: 0.6900, D: 1.3983, G: 0.6283
# Epoch 188/300 | AE: 0.6894, D: 1.4003, G: 0.6256
# Epoch 189/300 | AE: 0.6905, D: 1.3967, G: 0.6302
# Epoch 190/300 | AE: 0.6905, D: 1.3959, G: 0.6273
# Epoch 191/300 | AE: 0.6902, D: 1.3958, G: 0.6263
# Epoch 192/300 | AE: 0.6911, D: 1.4011, G: 0.6237
# Epoch 193/300 | AE: 0.6900, D: 1.3963, G: 0.6273
# Epoch 194/300 | AE: 0.6903, D: 1.4070, G: 0.6216
# Epoch 195/300 | AE: 0.6898, D: 1.4006, G: 0.6260
# Epoch 196/300 | AE: 0.6901, D: 1.3996, G: 0.6267
# Epoch 197/300 | AE: 0.6908, D: 1.4019, G: 0.6232
# Epoch 198/300 | AE: 0.6903, D: 1.4037, G: 0.6252
# Epoch 199/300 | AE: 0.6900, D: 1.3983, G: 0.6248
# Epoch 200/300 | AE: 0.6898, D: 1.4017, G: 0.6264
# Epoch 201/300 | AE: 0.6906, D: 1.3978, G: 0.6278
# Epoch 202/300 | AE: 0.6903, D: 1.4089, G: 0.6257
# Epoch 203/300 | AE: 0.6903, D: 1.4000, G: 0.6253
# Epoch 204/300 | AE: 0.6902, D: 1.3964, G: 0.6303
# Epoch 205/300 | AE: 0.6900, D: 1.3999, G: 0.6255
# Epoch 206/300 | AE: 0.6894, D: 1.3948, G: 0.6299
# Epoch 207/300 | AE: 0.6902, D: 1.4027, G: 0.6260
# Epoch 208/300 | AE: 0.6901, D: 1.3965, G: 0.6252
# Epoch 209/300 | AE: 0.6896, D: 1.3968, G: 0.6300
# Epoch 210/300 | AE: 0.6905, D: 1.4052, G: 0.6244
# Epoch 211/300 | AE: 0.6899, D: 1.3983, G: 0.6265
# Epoch 212/300 | AE: 0.6906, D: 1.3971, G: 0.6241
# Epoch 213/300 | AE: 0.6901, D: 1.3967, G: 0.6253
# Epoch 214/300 | AE: 0.6898, D: 1.4010, G: 0.6294
# Epoch 215/300 | AE: 0.6910, D: 1.3949, G: 0.6306
# Epoch 216/300 | AE: 0.6907, D: 1.4062, G: 0.6230
# Epoch 217/300 | AE: 0.6900, D: 1.3978, G: 0.6257
# Epoch 218/300 | AE: 0.6903, D: 1.4045, G: 0.6192
# Epoch 219/300 | AE: 0.6900, D: 1.3994, G: 0.6276
# Epoch 220/300 | AE: 0.6900, D: 1.4003, G: 0.6278
# Epoch 221/300 | AE: 0.6896, D: 1.3929, G: 0.6293
# Epoch 222/300 | AE: 0.6901, D: 1.3988, G: 0.6259
# Epoch 223/300 | AE: 0.6904, D: 1.3976, G: 0.6260
# Epoch 224/300 | AE: 0.6908, D: 1.3980, G: 0.6248
# Epoch 225/300 | AE: 0.6897, D: 1.3995, G: 0.6272
# Epoch 226/300 | AE: 0.6893, D: 1.4005, G: 0.6258
# Epoch 227/300 | AE: 0.6897, D: 1.4039, G: 0.6268
# Epoch 228/300 | AE: 0.6904, D: 1.3971, G: 0.6266
# Epoch 229/300 | AE: 0.6895, D: 1.4024, G: 0.6255
# Epoch 230/300 | AE: 0.6908, D: 1.4009, G: 0.6240
# Epoch 231/300 | AE: 0.6912, D: 1.3909, G: 0.6319
# Epoch 232/300 | AE: 0.6898, D: 1.4027, G: 0.6262
# Epoch 233/300 | AE: 0.6904, D: 1.3945, G: 0.6300
# Epoch 234/300 | AE: 0.6905, D: 1.3958, G: 0.6298
# Epoch 235/300 | AE: 0.6900, D: 1.3938, G: 0.6283
# Epoch 236/300 | AE: 0.6899, D: 1.3970, G: 0.6262
# Epoch 237/300 | AE: 0.6901, D: 1.3953, G: 0.6275
# Epoch 238/300 | AE: 0.6904, D: 1.3996, G: 0.6252
# Epoch 239/300 | AE: 0.6901, D: 1.4039, G: 0.6226
# Epoch 240/300 | AE: 0.6903, D: 1.4036, G: 0.6283
# Epoch 241/300 | AE: 0.6901, D: 1.3941, G: 0.6281
# Epoch 242/300 | AE: 0.6902, D: 1.3979, G: 0.6276
# Epoch 243/300 | AE: 0.6904, D: 1.3970, G: 0.6285
# Epoch 244/300 | AE: 0.6905, D: 1.3958, G: 0.6292
# Epoch 245/300 | AE: 0.6900, D: 1.3998, G: 0.6287
# Epoch 246/300 | AE: 0.6909, D: 1.3957, G: 0.6295
# Epoch 247/300 | AE: 0.6906, D: 1.3991, G: 0.6228
# Epoch 248/300 | AE: 0.6904, D: 1.4014, G: 0.6252
# Epoch 249/300 | AE: 0.6906, D: 1.3993, G: 0.6253
# Epoch 250/300 | AE: 0.6895, D: 1.3998, G: 0.6276
# Epoch 251/300 | AE: 0.6902, D: 1.4019, G: 0.6290
# Epoch 252/300 | AE: 0.6899, D: 1.4008, G: 0.6267
# Epoch 253/300 | AE: 0.6907, D: 1.3983, G: 0.6266
# Epoch 254/300 | AE: 0.6906, D: 1.3970, G: 0.6277
# Epoch 255/300 | AE: 0.6908, D: 1.3981, G: 0.6282
# Epoch 256/300 | AE: 0.6902, D: 1.3993, G: 0.6294
# Epoch 257/300 | AE: 0.6909, D: 1.3922, G: 0.6280
# Epoch 258/300 | AE: 0.6902, D: 1.3996, G: 0.6256
# Epoch 259/300 | AE: 0.6902, D: 1.3963, G: 0.6283
# Epoch 260/300 | AE: 0.6908, D: 1.4020, G: 0.6262
# Epoch 261/300 | AE: 0.6895, D: 1.3999, G: 0.6290
# Epoch 262/300 | AE: 0.6901, D: 1.3936, G: 0.6286
# Epoch 263/300 | AE: 0.6903, D: 1.3975, G: 0.6290
# Epoch 264/300 | AE: 0.6907, D: 1.3936, G: 0.6302
# Epoch 265/300 | AE: 0.6905, D: 1.3961, G: 0.6291
# Epoch 266/300 | AE: 0.6896, D: 1.3965, G: 0.6276
# Epoch 267/300 | AE: 0.6897, D: 1.4060, G: 0.6234
# Epoch 268/300 | AE: 0.6904, D: 1.4030, G: 0.6247
# Epoch 269/300 | AE: 0.6901, D: 1.4009, G: 0.6257
# Epoch 270/300 | AE: 0.6910, D: 1.3989, G: 0.6265
# Epoch 271/300 | AE: 0.6900, D: 1.3998, G: 0.6245
# Epoch 272/300 | AE: 0.6906, D: 1.4028, G: 0.6277
# Epoch 273/300 | AE: 0.6903, D: 1.4035, G: 0.6215
# Epoch 274/300 | AE: 0.6899, D: 1.4069, G: 0.6234
# Epoch 275/300 | AE: 0.6904, D: 1.4015, G: 0.6230
# Epoch 276/300 | AE: 0.6897, D: 1.3959, G: 0.6293
# Epoch 277/300 | AE: 0.6895, D: 1.3961, G: 0.6253
# Epoch 278/300 | AE: 0.6912, D: 1.4046, G: 0.6252
# Epoch 279/300 | AE: 0.6906, D: 1.4039, G: 0.6219
# Epoch 280/300 | AE: 0.6905, D: 1.4007, G: 0.6250
# Epoch 281/300 | AE: 0.6896, D: 1.3965, G: 0.6272
# Epoch 282/300 | AE: 0.6904, D: 1.3956, G: 0.6295
# Epoch 283/300 | AE: 0.6906, D: 1.3986, G: 0.6250
# Epoch 284/300 | AE: 0.6898, D: 1.3982, G: 0.6272
# Epoch 285/300 | AE: 0.6908, D: 1.3986, G: 0.6286
# Epoch 286/300 | AE: 0.6903, D: 1.3983, G: 0.6253
# Epoch 287/300 | AE: 0.6894, D: 1.4038, G: 0.6237
# Epoch 288/300 | AE: 0.6897, D: 1.3995, G: 0.6239
# Epoch 289/300 | AE: 0.6897, D: 1.3984, G: 0.6275
# Epoch 290/300 | AE: 0.6895, D: 1.4069, G: 0.6238
# Epoch 291/300 | AE: 0.6899, D: 1.3962, G: 0.6256
# Epoch 292/300 | AE: 0.6900, D: 1.3991, G: 0.6269
# Epoch 293/300 | AE: 0.6902, D: 1.4077, G: 0.6245
# Epoch 294/300 | AE: 0.6913, D: 1.4041, G: 0.6241
# Epoch 295/300 | AE: 0.6909, D: 1.3945, G: 0.6265
# Epoch 296/300 | AE: 0.6899, D: 1.3945, G: 0.6260
# Epoch 297/300 | AE: 0.6902, D: 1.3972, G: 0.6259
# Epoch 298/300 | AE: 0.6909, D: 1.4020, G: 0.6269
# Epoch 299/300 | AE: 0.6896, D: 1.3974, G: 0.6285
# Epoch 300/300 | AE: 0.6906, D: 1.4002, G: 0.6270

# %%
# --- Load Data ---
X_train, X_test = load_letter_data("datasets/letter-recognition-2.csv")
input_dim = X_train.shape[1]

# %% [markdown]
# ## Generate Synthetic Data

# %%
# --- Define X_train_real and related preprocessing variables ---
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# Don't use header=None here
df = pd.read_csv("datasets/letter-recognition-2.csv")

X_real = df.iloc[:, 1:]   # All columns except 'letter'
y_real = df.iloc[:, 0]    # 'letter' column

le = LabelEncoder()
y_encoded = le.fit_transform(y_real)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_real)

X_train_real, X_test_real, y_train_real, y_test_real = train_test_split(
    X_scaled, y_encoded, test_size=0.2, random_state=42
)

# %%
# --- Generate Synthetic Data ---
synthetic_data = medgan.generate_data(num_samples=len(X_train_real))
synthetic_data_scaled = scaler.transform(synthetic_data)  # Scale similarly
# Out:
# C:\Anaconda\envs\medgan_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# --- Generate Synthetic Data ---
synthetic_data = medgan.generate_data(num_samples=1000)
print("Generated Data Shape:", synthetic_data.shape)
# Out:
# Generated Data Shape: (1000, 16)

# %%
# --- Generate Synthetic Data ---
synthetic_data = medgan.generate_data(num_samples=1000)
print("Generated Data Shape:", synthetic_data.shape)
# Out:
# Generated Data Shape: (1000, 16)

# %% [markdown]
# ## Classifier Evaluation

# %%
# Encode target for XGBClassifier
le = LabelEncoder()
y_encoded = le.fit_transform(y_real)

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_real)

# Train-test split
X_train_real, X_test_real, y_train_real, y_test_real = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# %%
# --- Classifier Evaluation ---
models = {
    "Random Forest": RandomForestClassifier(random_state=42),
    "MLP Classifier": MLPClassifier(max_iter=300, random_state=42),
    "XGB Classifier": XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42),
    "Logistic Regression": LogisticRegression(max_iter=300, random_state=42)
}

results = {}
for name, model in models.items():
    model.fit(X_train_real, y_train_real)
    y_pred = model.predict(X_test_real)
    results[name] = {
        "Accuracy": accuracy_score(y_test_real, y_pred),
        "Precision": precision_score(y_test_real, y_pred, average='macro', zero_division=0),
        "Recall": recall_score(y_test_real, y_pred, average='macro', zero_division=0),
        "F1 Score": f1_score(y_test_real, y_pred, average='macro', zero_division=0)
    }

results_df = pd.DataFrame(results).T
print("\nClassifier Evaluation on Real Data:")
print(results_df)
# Out:
# C:\Anaconda\envs\medgan_env\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Anaconda\envs\medgan_env\lib\site-packages\xgboost\core.py:158: UserWarning: [21:05:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Classifier Evaluation on Real Data:
#                      Accuracy  Precision    Recall  F1 Score
# Random Forest         0.96125   0.961784  0.960185  0.960461
# MLP Classifier        0.95700   0.956456  0.956381  0.956184
# XGB Classifier        0.96225   0.962060  0.961441  0.961459
# Logistic Regression   0.78200   0.779501  0.780292  0.778645
