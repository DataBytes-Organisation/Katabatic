# %%
from medgan_model import Medgan
from Data_loader import load_bank_data
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
import pandas as pd
from sklearn.model_selection import KFold

# %%
from medgan_model import Medgan
from Data_loader import load_bank_data
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import KFold

# %%
# --- Load and preprocess real shuttle data ---
df = pd.read_csv("F:\\Assisgments\\team project A\\Models\\MedGAN Areeb\\Datasets\\bank_encoded.csv", header=None)
X_real = df.iloc[:, :-1]
y_real = df.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = load_bank_data("F:\\Assisgments\\team project A\\Models\\MedGAN Areeb\\Datasets\\bank_encoded.csv", test_size=0.2, n_shuffle=10)
input_dim = X_train.shape[1]

# %%
# --- Apply 5-Fold Cross Validation ---
kf = KFold(n_splits=5, shuffle=True, random_state=42)

for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
    print(f"\n===== Fold {fold+1} of 5 =====")
    
    # Prepare train and validation split
    X_tr, X_val = X_train[train_idx], X_train[val_idx]
    
    # Now use X_tr for training instead of X_train
# Out:
# ===== Fold 1 of 5 =====
#
# ===== Fold 2 of 5 =====
#
# ===== Fold 3 of 5 =====
#
# ===== Fold 4 of 5 =====
#
# ===== Fold 5 of 5 =====

# %%
# --- Initialize and Train MedGAN ---
medgan = Medgan(input_dim=input_dim, ae_loss_type='bce')
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002)
batch_size = 64
n_epochs = 300

for epoch in range(n_epochs):
    np.random.shuffle(X_tr)
    for i in range(0, len(X_tr), batch_size):
        batch = X_tr[i:i + batch_size]
        noise = np.random.normal(size=(batch.shape[0], medgan.random_dim))
        medgan.train_step(batch, noise)
    print(f"Epoch {epoch+1}/{n_epochs} completed")
# Out:
# c:\Users\hp\anaconda3\envs\tf_env\lib\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/300 completed
# Epoch 2/300 completed
# Epoch 3/300 completed
# Epoch 4/300 completed
# Epoch 5/300 completed
# Epoch 6/300 completed
# Epoch 7/300 completed
# Epoch 8/300 completed
# Epoch 9/300 completed
# Epoch 10/300 completed
# Epoch 11/300 completed
# Epoch 12/300 completed
# Epoch 13/300 completed
# Epoch 14/300 completed
# Epoch 15/300 completed
# Epoch 16/300 completed
# Epoch 17/300 completed
# Epoch 18/300 completed
# Epoch 19/300 completed
# Epoch 20/300 completed
# Epoch 21/300 completed
# Epoch 22/300 completed
# Epoch 23/300 completed
# Epoch 24/300 completed
# Epoch 25/300 completed
# Epoch 26/300 completed
# Epoch 27/300 completed
# Epoch 28/300 completed
# Epoch 29/300 completed
# Epoch 30/300 completed
# Epoch 31/300 completed
# Epoch 32/300 completed
# Epoch 33/300 completed
# Epoch 34/300 completed
# Epoch 35/300 completed
# Epoch 36/300 completed
# Epoch 37/300 completed
# Epoch 38/300 completed
# Epoch 39/300 completed
# Epoch 40/300 completed
# Epoch 41/300 completed
# Epoch 42/300 completed
# Epoch 43/300 completed
# Epoch 44/300 completed
# Epoch 45/300 completed
# Epoch 46/300 completed
# Epoch 47/300 completed
# Epoch 48/300 completed
# Epoch 49/300 completed
# Epoch 50/300 completed
# Epoch 51/300 completed
# Epoch 52/300 completed
# Epoch 53/300 completed
# Epoch 54/300 completed
# Epoch 55/300 completed
# Epoch 56/300 completed
# Epoch 57/300 completed
# Epoch 58/300 completed
# Epoch 59/300 completed
# Epoch 60/300 completed
# Epoch 61/300 completed
# Epoch 62/300 completed
# Epoch 63/300 completed
# Epoch 64/300 completed
# Epoch 65/300 completed
# Epoch 66/300 completed
# Epoch 67/300 completed
# Epoch 68/300 completed
# Epoch 69/300 completed
# Epoch 70/300 completed
# Epoch 71/300 completed
# Epoch 72/300 completed
# Epoch 73/300 completed
# Epoch 74/300 completed
# Epoch 75/300 completed
# Epoch 76/300 completed
# Epoch 77/300 completed
# Epoch 78/300 completed
# Epoch 79/300 completed
# Epoch 80/300 completed
# Epoch 81/300 completed
# Epoch 82/300 completed
# Epoch 83/300 completed
# Epoch 84/300 completed
# Epoch 85/300 completed
# Epoch 86/300 completed
# Epoch 87/300 completed
# Epoch 88/300 completed
# Epoch 89/300 completed
# Epoch 90/300 completed
# Epoch 91/300 completed
# Epoch 92/300 completed
# Epoch 93/300 completed
# Epoch 94/300 completed
# Epoch 95/300 completed
# Epoch 96/300 completed
# Epoch 97/300 completed
# Epoch 98/300 completed
# Epoch 99/300 completed
# Epoch 100/300 completed
# Epoch 101/300 completed
# Epoch 102/300 completed
# Epoch 103/300 completed
# Epoch 104/300 completed
# Epoch 105/300 completed
# Epoch 106/300 completed
# Epoch 107/300 completed
# Epoch 108/300 completed
# Epoch 109/300 completed
# Epoch 110/300 completed
# Epoch 111/300 completed
# Epoch 112/300 completed
# Epoch 113/300 completed
# Epoch 114/300 completed
# Epoch 115/300 completed
# Epoch 116/300 completed
# Epoch 117/300 completed
# Epoch 118/300 completed
# Epoch 119/300 completed
# Epoch 120/300 completed
# Epoch 121/300 completed
# Epoch 122/300 completed
# Epoch 123/300 completed
# Epoch 124/300 completed
# Epoch 125/300 completed
# Epoch 126/300 completed
# Epoch 127/300 completed
# Epoch 128/300 completed
# Epoch 129/300 completed
# Epoch 130/300 completed
# Epoch 131/300 completed
# Epoch 132/300 completed
# Epoch 133/300 completed
# Epoch 134/300 completed
# Epoch 135/300 completed
# Epoch 136/300 completed
# Epoch 137/300 completed
# Epoch 138/300 completed
# Epoch 139/300 completed
# Epoch 140/300 completed
# Epoch 141/300 completed
# Epoch 142/300 completed
# Epoch 143/300 completed
# Epoch 144/300 completed
# Epoch 145/300 completed
# Epoch 146/300 completed
# Epoch 147/300 completed
# Epoch 148/300 completed
# Epoch 149/300 completed
# Epoch 150/300 completed
# Epoch 151/300 completed
# Epoch 152/300 completed
# Epoch 153/300 completed
# Epoch 154/300 completed
# Epoch 155/300 completed
# Epoch 156/300 completed
# Epoch 157/300 completed
# Epoch 158/300 completed
# Epoch 159/300 completed
# Epoch 160/300 completed
# Epoch 161/300 completed
# Epoch 162/300 completed
# Epoch 163/300 completed
# Epoch 164/300 completed
# Epoch 165/300 completed
# Epoch 166/300 completed
# Epoch 167/300 completed
# Epoch 168/300 completed
# Epoch 169/300 completed
# Epoch 170/300 completed
# Epoch 171/300 completed
# Epoch 172/300 completed
# Epoch 173/300 completed
# Epoch 174/300 completed
# Epoch 175/300 completed
# Epoch 176/300 completed
# Epoch 177/300 completed
# Epoch 178/300 completed
# Epoch 179/300 completed
# Epoch 180/300 completed
# Epoch 181/300 completed
# Epoch 182/300 completed
# Epoch 183/300 completed
# Epoch 184/300 completed
# Epoch 185/300 completed
# Epoch 186/300 completed
# Epoch 187/300 completed
# Epoch 188/300 completed
# Epoch 189/300 completed
# Epoch 190/300 completed
# Epoch 191/300 completed
# Epoch 192/300 completed
# Epoch 193/300 completed
# Epoch 194/300 completed
# Epoch 195/300 completed
# Epoch 196/300 completed
# Epoch 197/300 completed
# Epoch 198/300 completed
# Epoch 199/300 completed
# Epoch 200/300 completed
# Epoch 201/300 completed
# Epoch 202/300 completed
# Epoch 203/300 completed
# Epoch 204/300 completed
# Epoch 205/300 completed
# Epoch 206/300 completed
# Epoch 207/300 completed
# Epoch 208/300 completed
# Epoch 209/300 completed
# Epoch 210/300 completed
# Epoch 211/300 completed
# Epoch 212/300 completed
# Epoch 213/300 completed
# Epoch 214/300 completed
# Epoch 215/300 completed
# Epoch 216/300 completed
# Epoch 217/300 completed
# Epoch 218/300 completed
# Epoch 219/300 completed
# Epoch 220/300 completed
# Epoch 221/300 completed
# Epoch 222/300 completed
# Epoch 223/300 completed
# Epoch 224/300 completed
# Epoch 225/300 completed
# Epoch 226/300 completed
# Epoch 227/300 completed
# Epoch 228/300 completed
# Epoch 229/300 completed
# Epoch 230/300 completed
# Epoch 231/300 completed
# Epoch 232/300 completed
# Epoch 233/300 completed
# Epoch 234/300 completed
# Epoch 235/300 completed
# Epoch 236/300 completed
# Epoch 237/300 completed
# Epoch 238/300 completed
# Epoch 239/300 completed
# Epoch 240/300 completed
# Epoch 241/300 completed
# Epoch 242/300 completed
# Epoch 243/300 completed
# Epoch 244/300 completed
# Epoch 245/300 completed
# Epoch 246/300 completed
# Epoch 247/300 completed
# Epoch 248/300 completed
# Epoch 249/300 completed
# Epoch 250/300 completed
# Epoch 251/300 completed
# Epoch 252/300 completed
# Epoch 253/300 completed
# Epoch 254/300 completed
# Epoch 255/300 completed
# Epoch 256/300 completed
# Epoch 257/300 completed
# Epoch 258/300 completed
# Epoch 259/300 completed
# Epoch 260/300 completed
# Epoch 261/300 completed
# Epoch 262/300 completed
# Epoch 263/300 completed
# Epoch 264/300 completed
# Epoch 265/300 completed
# Epoch 266/300 completed
# Epoch 267/300 completed
# Epoch 268/300 completed
# Epoch 269/300 completed
# Epoch 270/300 completed
# Epoch 271/300 completed
# Epoch 272/300 completed
# Epoch 273/300 completed
# Epoch 274/300 completed
# Epoch 275/300 completed
# Epoch 276/300 completed
# Epoch 277/300 completed
# Epoch 278/300 completed
# Epoch 279/300 completed
# Epoch 280/300 completed
# Epoch 281/300 completed
# Epoch 282/300 completed
# Epoch 283/300 completed
# Epoch 284/300 completed
# Epoch 285/300 completed
# Epoch 286/300 completed
# Epoch 287/300 completed
# Epoch 288/300 completed
# Epoch 289/300 completed
# Epoch 290/300 completed
# Epoch 291/300 completed
# Epoch 292/300 completed
# Epoch 293/300 completed
# Epoch 294/300 completed
# Epoch 295/300 completed
# Epoch 296/300 completed
# Epoch 297/300 completed
# Epoch 298/300 completed
# Epoch 299/300 completed
# Epoch 300/300 completed

# %%
medgan = Medgan(input_dim=input_dim, ae_loss_type='bce')
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002)

# %%
# --- Apply 5-Fold Cross Validation ---
kf = KFold(n_splits=5, shuffle=True, random_state=42)

for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
    print(f"\n===== Fold {fold+1} of 5 =====")
    
    # Prepare train and validation split
    X_tr, X_val = X_train[train_idx], X_train[val_idx]
    
    # Now use X_tr for training instead of X_train
# Out:
# ===== Fold 1 of 5 =====
#
# ===== Fold 2 of 5 =====
#
# ===== Fold 3 of 5 =====
#
# ===== Fold 4 of 5 =====
#
# ===== Fold 5 of 5 =====

# %%
# --- Training Loop ---
ae_losses, d_losses, g_losses = [], [], []

for epoch in range(n_epochs):
    np.random.shuffle(X_tr)
    for i in range(0, len(X_tr), batch_size):
        batch = X_tr[i:i + batch_size]
        noise = np.random.normal(size=(batch.shape[0], medgan.random_dim))
        ae_loss, d_loss, g_loss = medgan.train_step(batch, noise)

    ae_losses.append(ae_loss.numpy())
    d_losses.append(d_loss.numpy())
    g_losses.append(g_loss.numpy())

    print(f"Epoch {epoch + 1}/{n_epochs} | AE: {ae_loss:.4f}, D: {d_loss:.4f}, G: {g_loss:.4f}")
# Out:
# Epoch 1/300 | AE: 0.6954, D: 1.3638, G: 0.7844
# Epoch 2/300 | AE: 0.6906, D: 1.3680, G: 0.7877
# Epoch 3/300 | AE: 0.6923, D: 1.3622, G: 0.7882
# Epoch 4/300 | AE: 0.6925, D: 1.3692, G: 0.7815
# Epoch 5/300 | AE: 0.6909, D: 1.3642, G: 0.7841
# Epoch 6/300 | AE: 0.6932, D: 1.3731, G: 0.7845
# Epoch 7/300 | AE: 0.6954, D: 1.3633, G: 0.7828
# Epoch 8/300 | AE: 0.6924, D: 1.3625, G: 0.7827
# Epoch 9/300 | AE: 0.6924, D: 1.3709, G: 0.7847
# Epoch 10/300 | AE: 0.6947, D: 1.3700, G: 0.7823
# Epoch 11/300 | AE: 0.6935, D: 1.3858, G: 0.7818
# Epoch 12/300 | AE: 0.6931, D: 1.3698, G: 0.7882
# Epoch 13/300 | AE: 0.6941, D: 1.3636, G: 0.7836
# Epoch 14/300 | AE: 0.6948, D: 1.3811, G: 0.7804
# Epoch 15/300 | AE: 0.6942, D: 1.3618, G: 0.7850
# Epoch 16/300 | AE: 0.6924, D: 1.3682, G: 0.7820
# Epoch 17/300 | AE: 0.6941, D: 1.3679, G: 0.7877
# Epoch 18/300 | AE: 0.6938, D: 1.3678, G: 0.7853
# Epoch 19/300 | AE: 0.6937, D: 1.3575, G: 0.7835
# Epoch 20/300 | AE: 0.6947, D: 1.3719, G: 0.7867
# Epoch 21/300 | AE: 0.6928, D: 1.3603, G: 0.7860
# Epoch 22/300 | AE: 0.6938, D: 1.3692, G: 0.7796
# Epoch 23/300 | AE: 0.6933, D: 1.3707, G: 0.7830
# Epoch 24/300 | AE: 0.6904, D: 1.3686, G: 0.7879
# Epoch 25/300 | AE: 0.6920, D: 1.3688, G: 0.7880
# Epoch 26/300 | AE: 0.6951, D: 1.3599, G: 0.7847
# Epoch 27/300 | AE: 0.6915, D: 1.3794, G: 0.7845
# Epoch 28/300 | AE: 0.6934, D: 1.3624, G: 0.7801
# Epoch 29/300 | AE: 0.6924, D: 1.3651, G: 0.7821
# Epoch 30/300 | AE: 0.6927, D: 1.3679, G: 0.7848
# Epoch 31/300 | AE: 0.6948, D: 1.3732, G: 0.7887
# Epoch 32/300 | AE: 0.6928, D: 1.3685, G: 0.7865
# Epoch 33/300 | AE: 0.6934, D: 1.3640, G: 0.7883
# Epoch 34/300 | AE: 0.6931, D: 1.3692, G: 0.7860
# Epoch 35/300 | AE: 0.6932, D: 1.3588, G: 0.7834
# Epoch 36/300 | AE: 0.6918, D: 1.3706, G: 0.7857
# Epoch 37/300 | AE: 0.6932, D: 1.3690, G: 0.7804
# Epoch 38/300 | AE: 0.6923, D: 1.3678, G: 0.7853
# Epoch 39/300 | AE: 0.6951, D: 1.3617, G: 0.7827
# Epoch 40/300 | AE: 0.6935, D: 1.3657, G: 0.7796
# Epoch 41/300 | AE: 0.6941, D: 1.3702, G: 0.7880
# Epoch 42/300 | AE: 0.6929, D: 1.3809, G: 0.7826
# Epoch 43/300 | AE: 0.6929, D: 1.3624, G: 0.7879
# Epoch 44/300 | AE: 0.6932, D: 1.3652, G: 0.7837
# Epoch 45/300 | AE: 0.6938, D: 1.3602, G: 0.7889
# Epoch 46/300 | AE: 0.6950, D: 1.3638, G: 0.7877
# Epoch 47/300 | AE: 0.6917, D: 1.3677, G: 0.7882
# Epoch 48/300 | AE: 0.6932, D: 1.3566, G: 0.7874
# Epoch 49/300 | AE: 0.6949, D: 1.3591, G: 0.7843
# Epoch 50/300 | AE: 0.6926, D: 1.3694, G: 0.7853
# Epoch 51/300 | AE: 0.6935, D: 1.3579, G: 0.7841
# Epoch 52/300 | AE: 0.6909, D: 1.3757, G: 0.7845
# Epoch 53/300 | AE: 0.6923, D: 1.3692, G: 0.7860
# Epoch 54/300 | AE: 0.6935, D: 1.3610, G: 0.7871
# Epoch 55/300 | AE: 0.6927, D: 1.3596, G: 0.7844
# Epoch 56/300 | AE: 0.6920, D: 1.3647, G: 0.7846
# Epoch 57/300 | AE: 0.6929, D: 1.3715, G: 0.7830
# Epoch 58/300 | AE: 0.6919, D: 1.3608, G: 0.7873
# Epoch 59/300 | AE: 0.6946, D: 1.3634, G: 0.7810
# Epoch 60/300 | AE: 0.6931, D: 1.3787, G: 0.7835
# Epoch 61/300 | AE: 0.6915, D: 1.3643, G: 0.7863
# Epoch 62/300 | AE: 0.6924, D: 1.3736, G: 0.7872
# Epoch 63/300 | AE: 0.6925, D: 1.3679, G: 0.7852
# Epoch 64/300 | AE: 0.6923, D: 1.3696, G: 0.7857
# Epoch 65/300 | AE: 0.6921, D: 1.3644, G: 0.7853
# Epoch 66/300 | AE: 0.6908, D: 1.3691, G: 0.7860
# Epoch 67/300 | AE: 0.6920, D: 1.3614, G: 0.7820
# Epoch 68/300 | AE: 0.6933, D: 1.3640, G: 0.7884
# Epoch 69/300 | AE: 0.6923, D: 1.3754, G: 0.7883
# Epoch 70/300 | AE: 0.6921, D: 1.3668, G: 0.7829
# Epoch 71/300 | AE: 0.6924, D: 1.3636, G: 0.7869
# Epoch 72/300 | AE: 0.6925, D: 1.3669, G: 0.7845
# Epoch 73/300 | AE: 0.6944, D: 1.3620, G: 0.7868
# Epoch 74/300 | AE: 0.6919, D: 1.3727, G: 0.7829
# Epoch 75/300 | AE: 0.6936, D: 1.3722, G: 0.7885
# Epoch 76/300 | AE: 0.6949, D: 1.3544, G: 0.7878
# Epoch 77/300 | AE: 0.6952, D: 1.3597, G: 0.7832
# Epoch 78/300 | AE: 0.6939, D: 1.3629, G: 0.7874
# Epoch 79/300 | AE: 0.6935, D: 1.3791, G: 0.7833
# Epoch 80/300 | AE: 0.6938, D: 1.3632, G: 0.7837
# Epoch 81/300 | AE: 0.6939, D: 1.3671, G: 0.7825
# Epoch 82/300 | AE: 0.6955, D: 1.3658, G: 0.7828
# Epoch 83/300 | AE: 0.6940, D: 1.3680, G: 0.7847
# Epoch 84/300 | AE: 0.6924, D: 1.3761, G: 0.7884
# Epoch 85/300 | AE: 0.6940, D: 1.3674, G: 0.7861
# Epoch 86/300 | AE: 0.6924, D: 1.3727, G: 0.7843
# Epoch 87/300 | AE: 0.6922, D: 1.3741, G: 0.7827
# Epoch 88/300 | AE: 0.6930, D: 1.3676, G: 0.7896
# Epoch 89/300 | AE: 0.6935, D: 1.3666, G: 0.7846
# Epoch 90/300 | AE: 0.6943, D: 1.3655, G: 0.7901
# Epoch 91/300 | AE: 0.6928, D: 1.3641, G: 0.7846
# Epoch 92/300 | AE: 0.6919, D: 1.3610, G: 0.7897
# Epoch 93/300 | AE: 0.6937, D: 1.3644, G: 0.7860
# Epoch 94/300 | AE: 0.6937, D: 1.3593, G: 0.7869
# Epoch 95/300 | AE: 0.6931, D: 1.3692, G: 0.7825
# Epoch 96/300 | AE: 0.6927, D: 1.3686, G: 0.7864
# Epoch 97/300 | AE: 0.6926, D: 1.3605, G: 0.7904
# Epoch 98/300 | AE: 0.6955, D: 1.3624, G: 0.7912
# Epoch 99/300 | AE: 0.6947, D: 1.3543, G: 0.7877
# Epoch 100/300 | AE: 0.6922, D: 1.3698, G: 0.7895
# Epoch 101/300 | AE: 0.6911, D: 1.3695, G: 0.7864
# Epoch 102/300 | AE: 0.6957, D: 1.3572, G: 0.7874
# Epoch 103/300 | AE: 0.6914, D: 1.3793, G: 0.7860
# Epoch 104/300 | AE: 0.6928, D: 1.3516, G: 0.7883
# Epoch 105/300 | AE: 0.6921, D: 1.3695, G: 0.7841
# Epoch 106/300 | AE: 0.6932, D: 1.3638, G: 0.7854
# Epoch 107/300 | AE: 0.6932, D: 1.3737, G: 0.7841
# Epoch 108/300 | AE: 0.6931, D: 1.3557, G: 0.7899
# Epoch 109/300 | AE: 0.6933, D: 1.3567, G: 0.7870
# Epoch 110/300 | AE: 0.6951, D: 1.3648, G: 0.7838
# Epoch 111/300 | AE: 0.6933, D: 1.3580, G: 0.7906
# Epoch 112/300 | AE: 0.6948, D: 1.3734, G: 0.7843
# Epoch 113/300 | AE: 0.6924, D: 1.3785, G: 0.7841
# Epoch 114/300 | AE: 0.6934, D: 1.3567, G: 0.7866
# Epoch 115/300 | AE: 0.6933, D: 1.3615, G: 0.7866
# Epoch 116/300 | AE: 0.6929, D: 1.3683, G: 0.7872
# Epoch 117/300 | AE: 0.6936, D: 1.3521, G: 0.7829
# Epoch 118/300 | AE: 0.6932, D: 1.3678, G: 0.7867
# Epoch 119/300 | AE: 0.6915, D: 1.3675, G: 0.7813
# Epoch 120/300 | AE: 0.6924, D: 1.3638, G: 0.7832
# Epoch 121/300 | AE: 0.6936, D: 1.3559, G: 0.7842
# Epoch 122/300 | AE: 0.6913, D: 1.3694, G: 0.7892
# Epoch 123/300 | AE: 0.6932, D: 1.3640, G: 0.7842
# Epoch 124/300 | AE: 0.6955, D: 1.3563, G: 0.7867
# Epoch 125/300 | AE: 0.6943, D: 1.3778, G: 0.7823
# Epoch 126/300 | AE: 0.6947, D: 1.3597, G: 0.7884
# Epoch 127/300 | AE: 0.6935, D: 1.3662, G: 0.7840
# Epoch 128/300 | AE: 0.6933, D: 1.3684, G: 0.7877
# Epoch 129/300 | AE: 0.6931, D: 1.3750, G: 0.7832
# Epoch 130/300 | AE: 0.6915, D: 1.3671, G: 0.7854
# Epoch 131/300 | AE: 0.6919, D: 1.3737, G: 0.7805
# Epoch 132/300 | AE: 0.6922, D: 1.3569, G: 0.7876
# Epoch 133/300 | AE: 0.6924, D: 1.3663, G: 0.7838
# Epoch 134/300 | AE: 0.6942, D: 1.3605, G: 0.7842
# Epoch 135/300 | AE: 0.6936, D: 1.3734, G: 0.7852
# Epoch 136/300 | AE: 0.6943, D: 1.3632, G: 0.7849
# Epoch 137/300 | AE: 0.6923, D: 1.3768, G: 0.7906
# Epoch 138/300 | AE: 0.6941, D: 1.3667, G: 0.7849
# Epoch 139/300 | AE: 0.6946, D: 1.3632, G: 0.7828
# Epoch 140/300 | AE: 0.6959, D: 1.3573, G: 0.7891
# Epoch 141/300 | AE: 0.6907, D: 1.3658, G: 0.7839
# Epoch 142/300 | AE: 0.6937, D: 1.3737, G: 0.7829
# Epoch 143/300 | AE: 0.6949, D: 1.3654, G: 0.7856
# Epoch 144/300 | AE: 0.6923, D: 1.3749, G: 0.7849
# Epoch 145/300 | AE: 0.6938, D: 1.3751, G: 0.7858
# Epoch 146/300 | AE: 0.6925, D: 1.3803, G: 0.7870
# Epoch 147/300 | AE: 0.6912, D: 1.3735, G: 0.7863
# Epoch 148/300 | AE: 0.6945, D: 1.3680, G: 0.7858
# Epoch 149/300 | AE: 0.6928, D: 1.3618, G: 0.7884
# Epoch 150/300 | AE: 0.6941, D: 1.3663, G: 0.7848
# Epoch 151/300 | AE: 0.6950, D: 1.3566, G: 0.7862
# Epoch 152/300 | AE: 0.6916, D: 1.3636, G: 0.7877
# Epoch 153/300 | AE: 0.6937, D: 1.3799, G: 0.7837
# Epoch 154/300 | AE: 0.6956, D: 1.3700, G: 0.7866
# Epoch 155/300 | AE: 0.6940, D: 1.3695, G: 0.7834
# Epoch 156/300 | AE: 0.6945, D: 1.3668, G: 0.7845
# Epoch 157/300 | AE: 0.6913, D: 1.3760, G: 0.7878
# Epoch 158/300 | AE: 0.6922, D: 1.3626, G: 0.7853
# Epoch 159/300 | AE: 0.6940, D: 1.3601, G: 0.7901
# Epoch 160/300 | AE: 0.6937, D: 1.3613, G: 0.7858
# Epoch 161/300 | AE: 0.6936, D: 1.3731, G: 0.7847
# Epoch 162/300 | AE: 0.6906, D: 1.3647, G: 0.7858
# Epoch 163/300 | AE: 0.6916, D: 1.3834, G: 0.7804
# Epoch 164/300 | AE: 0.6931, D: 1.3646, G: 0.7853
# Epoch 165/300 | AE: 0.6924, D: 1.3758, G: 0.7851
# Epoch 166/300 | AE: 0.6944, D: 1.3548, G: 0.7858
# Epoch 167/300 | AE: 0.6957, D: 1.3640, G: 0.7864
# Epoch 168/300 | AE: 0.6931, D: 1.3683, G: 0.7853
# Epoch 169/300 | AE: 0.6934, D: 1.3777, G: 0.7853
# Epoch 170/300 | AE: 0.6944, D: 1.3684, G: 0.7886
# Epoch 171/300 | AE: 0.6936, D: 1.3649, G: 0.7856
# Epoch 172/300 | AE: 0.6920, D: 1.3706, G: 0.7869
# Epoch 173/300 | AE: 0.6944, D: 1.3670, G: 0.7834
# Epoch 174/300 | AE: 0.6926, D: 1.3648, G: 0.7853
# Epoch 175/300 | AE: 0.6942, D: 1.3610, G: 0.7853
# Epoch 176/300 | AE: 0.6897, D: 1.3674, G: 0.7836
# Epoch 177/300 | AE: 0.6937, D: 1.3686, G: 0.7806
# Epoch 178/300 | AE: 0.6919, D: 1.3755, G: 0.7852
# Epoch 179/300 | AE: 0.6947, D: 1.3581, G: 0.7875
# Epoch 180/300 | AE: 0.6923, D: 1.3659, G: 0.7861
# Epoch 181/300 | AE: 0.6949, D: 1.3719, G: 0.7840
# Epoch 182/300 | AE: 0.6932, D: 1.3598, G: 0.7872
# Epoch 183/300 | AE: 0.6897, D: 1.3655, G: 0.7890
# Epoch 184/300 | AE: 0.6938, D: 1.3670, G: 0.7896
# Epoch 185/300 | AE: 0.6942, D: 1.3695, G: 0.7806
# Epoch 186/300 | AE: 0.6920, D: 1.3672, G: 0.7848
# Epoch 187/300 | AE: 0.6919, D: 1.3604, G: 0.7818
# Epoch 188/300 | AE: 0.6946, D: 1.3603, G: 0.7846
# Epoch 189/300 | AE: 0.6933, D: 1.3808, G: 0.7817
# Epoch 190/300 | AE: 0.6934, D: 1.3703, G: 0.7885
# Epoch 191/300 | AE: 0.6946, D: 1.3780, G: 0.7832
# Epoch 192/300 | AE: 0.6913, D: 1.3778, G: 0.7832
# Epoch 193/300 | AE: 0.6926, D: 1.3706, G: 0.7889
# Epoch 194/300 | AE: 0.6951, D: 1.3702, G: 0.7825
# Epoch 195/300 | AE: 0.6941, D: 1.3709, G: 0.7865
# Epoch 196/300 | AE: 0.6925, D: 1.3656, G: 0.7853
# Epoch 197/300 | AE: 0.6936, D: 1.3601, G: 0.7883
# Epoch 198/300 | AE: 0.6922, D: 1.3675, G: 0.7840
# Epoch 199/300 | AE: 0.6926, D: 1.3689, G: 0.7839
# Epoch 200/300 | AE: 0.6920, D: 1.3757, G: 0.7854
# Epoch 201/300 | AE: 0.6936, D: 1.3677, G: 0.7820
# Epoch 202/300 | AE: 0.6955, D: 1.3598, G: 0.7878
# Epoch 203/300 | AE: 0.6914, D: 1.3709, G: 0.7847
# Epoch 204/300 | AE: 0.6928, D: 1.3782, G: 0.7873
# Epoch 205/300 | AE: 0.6925, D: 1.3687, G: 0.7875
# Epoch 206/300 | AE: 0.6934, D: 1.3643, G: 0.7873
# Epoch 207/300 | AE: 0.6936, D: 1.3767, G: 0.7842
# Epoch 208/300 | AE: 0.6942, D: 1.3624, G: 0.7822
# Epoch 209/300 | AE: 0.6937, D: 1.3782, G: 0.7848
# Epoch 210/300 | AE: 0.6917, D: 1.3700, G: 0.7858
# Epoch 211/300 | AE: 0.6912, D: 1.3692, G: 0.7871
# Epoch 212/300 | AE: 0.6936, D: 1.3791, G: 0.7836
# Epoch 213/300 | AE: 0.6931, D: 1.3625, G: 0.7844
# Epoch 214/300 | AE: 0.6935, D: 1.3677, G: 0.7831
# Epoch 215/300 | AE: 0.6931, D: 1.3773, G: 0.7857
# Epoch 216/300 | AE: 0.6926, D: 1.3624, G: 0.7887
# Epoch 217/300 | AE: 0.6935, D: 1.3634, G: 0.7886
# Epoch 218/300 | AE: 0.6930, D: 1.3750, G: 0.7813
# Epoch 219/300 | AE: 0.6947, D: 1.3689, G: 0.7838
# Epoch 220/300 | AE: 0.6920, D: 1.3582, G: 0.7912
# Epoch 221/300 | AE: 0.6913, D: 1.3691, G: 0.7856
# Epoch 222/300 | AE: 0.6921, D: 1.3571, G: 0.7854
# Epoch 223/300 | AE: 0.6929, D: 1.3683, G: 0.7851
# Epoch 224/300 | AE: 0.6928, D: 1.3617, G: 0.7899
# Epoch 225/300 | AE: 0.6944, D: 1.3644, G: 0.7875
# Epoch 226/300 | AE: 0.6944, D: 1.3559, G: 0.7853
# Epoch 227/300 | AE: 0.6968, D: 1.3632, G: 0.7863
# Epoch 228/300 | AE: 0.6901, D: 1.3663, G: 0.7890
# Epoch 229/300 | AE: 0.6932, D: 1.3753, G: 0.7831
# Epoch 230/300 | AE: 0.6931, D: 1.3635, G: 0.7837
# Epoch 231/300 | AE: 0.6951, D: 1.3612, G: 0.7863
# Epoch 232/300 | AE: 0.6937, D: 1.3718, G: 0.7805
# Epoch 233/300 | AE: 0.6961, D: 1.3661, G: 0.7894
# Epoch 234/300 | AE: 0.6915, D: 1.3609, G: 0.7834
# Epoch 235/300 | AE: 0.6913, D: 1.3758, G: 0.7858
# Epoch 236/300 | AE: 0.6926, D: 1.3740, G: 0.7837
# Epoch 237/300 | AE: 0.6936, D: 1.3636, G: 0.7902
# Epoch 238/300 | AE: 0.6947, D: 1.3710, G: 0.7833
# Epoch 239/300 | AE: 0.6910, D: 1.3682, G: 0.7861
# Epoch 240/300 | AE: 0.6931, D: 1.3663, G: 0.7832
# Epoch 241/300 | AE: 0.6923, D: 1.3777, G: 0.7827
# Epoch 242/300 | AE: 0.6916, D: 1.3679, G: 0.7856
# Epoch 243/300 | AE: 0.6912, D: 1.3750, G: 0.7846
# Epoch 244/300 | AE: 0.6928, D: 1.3662, G: 0.7870
# Epoch 245/300 | AE: 0.6925, D: 1.3648, G: 0.7892
# Epoch 246/300 | AE: 0.6940, D: 1.3688, G: 0.7876
# Epoch 247/300 | AE: 0.6931, D: 1.3726, G: 0.7836
# Epoch 248/300 | AE: 0.6943, D: 1.3651, G: 0.7815
# Epoch 249/300 | AE: 0.6950, D: 1.3539, G: 0.7859
# Epoch 250/300 | AE: 0.6919, D: 1.3766, G: 0.7841
# Epoch 251/300 | AE: 0.6935, D: 1.3606, G: 0.7831
# Epoch 252/300 | AE: 0.6922, D: 1.3749, G: 0.7858
# Epoch 253/300 | AE: 0.6948, D: 1.3669, G: 0.7873
# Epoch 254/300 | AE: 0.6911, D: 1.3616, G: 0.7873
# Epoch 255/300 | AE: 0.6915, D: 1.3622, G: 0.7881
# Epoch 256/300 | AE: 0.6923, D: 1.3663, G: 0.7854
# Epoch 257/300 | AE: 0.6941, D: 1.3666, G: 0.7870
# Epoch 258/300 | AE: 0.6933, D: 1.3703, G: 0.7828
# Epoch 259/300 | AE: 0.6909, D: 1.3637, G: 0.7846
# Epoch 260/300 | AE: 0.6926, D: 1.3651, G: 0.7862
# Epoch 261/300 | AE: 0.6907, D: 1.3737, G: 0.7862
# Epoch 262/300 | AE: 0.6936, D: 1.3749, G: 0.7930
# Epoch 263/300 | AE: 0.6931, D: 1.3799, G: 0.7835
# Epoch 264/300 | AE: 0.6934, D: 1.3639, G: 0.7855
# Epoch 265/300 | AE: 0.6919, D: 1.3600, G: 0.7840
# Epoch 266/300 | AE: 0.6937, D: 1.3665, G: 0.7864
# Epoch 267/300 | AE: 0.6934, D: 1.3675, G: 0.7889
# Epoch 268/300 | AE: 0.6919, D: 1.3631, G: 0.7881
# Epoch 269/300 | AE: 0.6937, D: 1.3637, G: 0.7843
# Epoch 270/300 | AE: 0.6926, D: 1.3746, G: 0.7852
# Epoch 271/300 | AE: 0.6932, D: 1.3575, G: 0.7862
# Epoch 272/300 | AE: 0.6932, D: 1.3772, G: 0.7821
# Epoch 273/300 | AE: 0.6929, D: 1.3580, G: 0.7856
# Epoch 274/300 | AE: 0.6932, D: 1.3603, G: 0.7843
# Epoch 275/300 | AE: 0.6924, D: 1.3569, G: 0.7871
# Epoch 276/300 | AE: 0.6929, D: 1.3700, G: 0.7860
# Epoch 277/300 | AE: 0.6948, D: 1.3640, G: 0.7840
# Epoch 278/300 | AE: 0.6939, D: 1.3577, G: 0.7855
# Epoch 279/300 | AE: 0.6925, D: 1.3770, G: 0.7813
# Epoch 280/300 | AE: 0.6947, D: 1.3687, G: 0.7855
# Epoch 281/300 | AE: 0.6933, D: 1.3656, G: 0.7884
# Epoch 282/300 | AE: 0.6936, D: 1.3558, G: 0.7863
# Epoch 283/300 | AE: 0.6928, D: 1.3629, G: 0.7839
# Epoch 284/300 | AE: 0.6945, D: 1.3626, G: 0.7834
# Epoch 285/300 | AE: 0.6932, D: 1.3706, G: 0.7855
# Epoch 286/300 | AE: 0.6931, D: 1.3589, G: 0.7836
# Epoch 287/300 | AE: 0.6921, D: 1.3796, G: 0.7801
# Epoch 288/300 | AE: 0.6945, D: 1.3742, G: 0.7820
# Epoch 289/300 | AE: 0.6939, D: 1.3658, G: 0.7868
# Epoch 290/300 | AE: 0.6929, D: 1.3691, G: 0.7866
# Epoch 291/300 | AE: 0.6921, D: 1.3644, G: 0.7845
# Epoch 292/300 | AE: 0.6929, D: 1.3534, G: 0.7857
# Epoch 293/300 | AE: 0.6923, D: 1.3664, G: 0.7858
# Epoch 294/300 | AE: 0.6929, D: 1.3658, G: 0.7892
# Epoch 295/300 | AE: 0.6949, D: 1.3676, G: 0.7859
# Epoch 296/300 | AE: 0.6928, D: 1.3617, G: 0.7865
# Epoch 297/300 | AE: 0.6956, D: 1.3625, G: 0.7857
# Epoch 298/300 | AE: 0.6914, D: 1.3604, G: 0.7850
# Epoch 299/300 | AE: 0.6927, D: 1.3729, G: 0.7851
# Epoch 300/300 | AE: 0.6934, D: 1.3615, G: 0.7819

# %%
# --- Define X_train_real and related preprocessing variables ---
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

df = pd.read_csv("F:\\Assisgments\\team project A\\Models\\MedGAN Areeb\\Datasets\\bank_encoded.csv", header=None)
X_real = df.iloc[:, :-1]
y_real = df.iloc[:, -1]

le = LabelEncoder()
y_encoded = le.fit_transform(y_real)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_real)

X_train_real, X_test_real, y_train_real, y_test_real = train_test_split(
    X_scaled, y_encoded, test_size=0.2, random_state=42
)

from sklearn.model_selection import KFold

# %%
# Generate Synthetic Data
synthetic_data = medgan.generate_data(num_samples=len(X_train_real))

# %%
# --- Generate Synthetic Data ---
synthetic_data = medgan.generate_data(num_samples=1000)
print("Generated Data Shape:", synthetic_data.shape)
# Out:
# Generated Data Shape: (1000, 13)

# %%
# Encode target for XGBClassifier
le = LabelEncoder()
y_encoded = le.fit_transform(y_real)

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_real)

# Train-test split
X_train_real, X_test_real, y_train_real, y_test_real = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# %%
# --- Classifier Evaluation ---
models = {
    "Random Forest": RandomForestClassifier(random_state=42),
    "MLP Classifier": MLPClassifier(max_iter=300, random_state=42),
    "XGB Classifier": XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42),
    "Logistic Regression": LogisticRegression(max_iter=300, random_state=42)
}

results = {}
for name, model in models.items():
    model.fit(X_train_real, y_train_real)
    y_pred = model.predict(X_test_real)
    results[name] = {
        "Accuracy": accuracy_score(y_test_real, y_pred),
        "Precision": precision_score(y_test_real, y_pred, average='macro', zero_division=0),
        "Recall": recall_score(y_test_real, y_pred, average='macro', zero_division=0),
        "F1 Score": f1_score(y_test_real, y_pred, average='macro', zero_division=0)
    }

results_df = pd.DataFrame(results).T
print("\nClassifier Evaluation on Real Data:")
print(results_df)
# Out:
# c:\Users\hp\anaconda3\envs\tf_env\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\hp\anaconda3\envs\tf_env\lib\site-packages\xgboost\core.py:158: UserWarning: [15:34:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Classifier Evaluation on Real Data:
#                      Accuracy  Precision    Recall  F1 Score
# Random Forest        0.743257   0.735320  0.577315  0.567604
# MLP Classifier       0.725275   0.654429  0.582012  0.582033
# XGB Classifier       0.708292   0.617088  0.565973  0.563138
# Logistic Regression  0.757243   0.811241  0.589202  0.582126

# %%
# --- Plot Losses ---
plt.plot(ae_losses, label='Autoencoder Loss')
plt.plot(d_losses, label='Discriminator Loss')
plt.plot(g_losses, label='Generator Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Training Loss Curves")
plt.show()
